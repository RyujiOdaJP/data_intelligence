# %% [markdown]
# <img src='slides/5.png'>

# %%
import pandas as pd
import numpy as np

# DataFrameに読み込み
import pandas as pd
df = pd.read_csv('data/14_2_cleansing.csv')
df.head()
# Out:
#    height  weight  age
# 0     180      65   18
# 1     175      68   20
# 2     170      55   25
# 3     165      65   30
# 4     170      70   35

# %%
# DataFrameの要約統計量を表示
df.describe()
# Out:
#             height       weight        age
# count    16.000000    16.000000  16.000000
# mean    775.562500   682.000000  67.437500
# std    2459.967424  2484.608836  37.209262
# min       0.000000     0.000000  18.000000
# 25%     165.000000    55.000000  28.750000
# 50%     175.000000    66.500000  99.000000
# 75%     180.000000    71.250000  99.000000
# max    9999.000000  9999.000000  99.000000

# %% [markdown]
# min, max の値が不自然であり、その結果 mean, std もおかしな値になっている

# %%
# 各列の値の数を表示
for c in df.columns:
    print(df.groupby(c).size(), '\n')
# Out:
# height
# 0       1
# 160     2
# 165     2
# 170     2
# 175     4
# 180     4
# 9999    1
# dtype: int64
#
# weight
# 0       1
# 45      1
# 50      1
# 55      2
# 60      1
# 65      2
# 68      1
# 70      3
# 75      1
# 80      1
# 85      1
# 9999    1
# dtype: int64
#
# age
# 18    1
# 20    1
# 25    2
# 30    1
# 35    2
# 99    9
# dtype: int64

# %%
# 値の範囲が大きすぎて見にくいならば、最初と最後にしぼって表示
for c in df.columns:
    print(df.groupby(c).size().head(3), '\n')
    print(df.groupby(c).size().tail(3), '\n')
# Out:
# height
# 0      1
# 160    2
# 165    2
# dtype: int64
#
# height
# 175     4
# 180     4
# 9999    1
# dtype: int64
#
# weight
# 0     1
# 45    1
# 50    1
# dtype: int64
#
# weight
# 80      1
# 85      1
# 9999    1
# dtype: int64
#
# age
# 18    1
# 20    1
# 25    2
# dtype: int64
#
# age
# 30    1
# 35    2
# 99    9
# dtype: int64

# %%
# 欠損値扱いの値を欠損値 NaN に置換
df['height'] = df['height'].replace(0, np.nan)
df['height'] = df['height'].replace(9999, np.nan)
df['weight'] = df['weight'].replace(0, np.nan)
df['weight'] = df['weight'].replace(9999, np.nan)
df['age'] = df['age'].replace(99, np.nan)

# 確認
df
# Out:
#     height  weight   age
# 0    180.0    65.0  18.0
# 1    175.0    68.0  20.0
# 2    170.0    55.0  25.0
# 3    165.0    65.0  30.0
# 4    170.0    70.0  35.0
# 5      NaN     NaN  25.0
# 6      NaN     NaN  35.0
# 7    165.0    45.0   NaN
# 8    160.0    55.0   NaN
# 9    180.0    85.0   NaN
# 10   175.0    60.0   NaN
# 11   180.0    70.0   NaN
# 12   175.0    70.0   NaN
# 13   160.0    50.0   NaN
# 14   180.0    80.0   NaN
# 15   175.0    75.0   NaN

# %% [markdown]
# <img src='slides/7.png'>

# %%
# NumPyの行列を作成し、0で割った結果が nan, inf となることを確認
a = np.arange(5)

# a の値を確認
print(a)

# a/0 の値を確認
# - 0/0 -> nan
# - 1/0 -> inf
print(a/0)
# Out:
# [0 1 2 3 4]
# [nan inf inf inf inf]
# /tmp/ipykernel_615/1238004266.py:10: RuntimeWarning: divide by zero encountered in true_divide
#   print(a/0)
# /tmp/ipykernel_615/1238004266.py:10: RuntimeWarning: invalid value encountered in true_divide
#   print(a/0)

# %% [markdown]
# ### 欠損値の有無の確認
#
# - isna(): 欠損値の場合にTrue
# - notnull(): 欠損値の場合にFalse（欠損値ではない場合にTrue）

# %%
# 欠損値の数をカウント
df.isna().sum()
# Out:
# height    2
# weight    2
# age       9
# dtype: int64

# %%
# 欠損値では無い値の数をカウント
df.notnull().sum()
# Out:
# height    14
# weight    14
# age        7
# dtype: int64

# %% [markdown]
# <img src='slides/11.png'>

# %% [markdown]
# ### 欠損値のある行の除去（リストワイズ法）
#
# - dropna()

# %%
# NaNを含む行を全て削除したDataFrame
df.dropna()
# Out:
#    height  weight   age
# 0   180.0    65.0  18.0
# 1   175.0    68.0  20.0
# 2   170.0    55.0  25.0
# 3   165.0    65.0  30.0
# 4   170.0    70.0  35.0

# %%
# age列でNaNを含む行を全て削除したDataFrame
df.dropna(subset=['age'])
# Out:
#    height  weight   age
# 0   180.0    65.0  18.0
# 1   175.0    68.0  20.0
# 2   170.0    55.0  25.0
# 3   165.0    65.0  30.0
# 4   170.0    70.0  35.0
# 5     NaN     NaN  25.0
# 6     NaN     NaN  35.0

# %% [markdown]
# ### 欠損値の置き換え（代入法）
#
# - fillna()

# %%
# NaNを -1 に置き換え
df.fillna(-1)
# Out:
#     height  weight   age
# 0    180.0    65.0  18.0
# 1    175.0    68.0  20.0
# 2    170.0    55.0  25.0
# 3    165.0    65.0  30.0
# 4    170.0    70.0  35.0
# 5     -1.0    -1.0  25.0
# 6     -1.0    -1.0  35.0
# 7    165.0    45.0  -1.0
# 8    160.0    55.0  -1.0
# 9    180.0    85.0  -1.0
# 10   175.0    60.0  -1.0
# 11   180.0    70.0  -1.0
# 12   175.0    70.0  -1.0
# 13   160.0    50.0  -1.0
# 14   180.0    80.0  -1.0
# 15   175.0    75.0  -1.0

# %%
# NaNを平均値に置き換え（平均値代入法）
df.fillna(df.mean())
# Out:
#         height     weight        age
# 0   180.000000  65.000000  18.000000
# 1   175.000000  68.000000  20.000000
# 2   170.000000  55.000000  25.000000
# 3   165.000000  65.000000  30.000000
# 4   170.000000  70.000000  35.000000
# 5   172.142857  65.214286  25.000000
# 6   172.142857  65.214286  35.000000
# 7   165.000000  45.000000  26.857143
# 8   160.000000  55.000000  26.857143
# 9   180.000000  85.000000  26.857143
# 10  175.000000  60.000000  26.857143
# 11  180.000000  70.000000  26.857143
# 12  175.000000  70.000000  26.857143
# 13  160.000000  50.000000  26.857143
# 14  180.000000  80.000000  26.857143
# 15  175.000000  75.000000  26.857143
